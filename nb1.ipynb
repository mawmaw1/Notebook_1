# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql postgresql://appdev@data/appdev
# Out:
# 'Connected: appdev@appdev'

# %%
# %sql SELECT * FROM information_schema.tables;
# Out:
# 240 rows affected.
# [('appdev', 'chinook', 'invoice', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'chinook', 'customer', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'chinook', 'mediatype', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'chinook', 'playlist', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'eav', 'support', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'chinook', 'genre', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'chinook', 'invoiceline', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_type', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'chinook', 'track', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
# ...

# %%
# %sql SELECT table_name FROM information_schema.tables;
# Out:
# 240 rows affected.
# [('invoice',),
#  ('customer',),
#  ('mediatype',),
#  ('playlist',),
#  ('support',),
#  ('genre',),
#  ('invoiceline',),
#  ('pg_type',),
#  ('track',),
#  ('playlisttrack',),
#  ('customer',),
#  ('params',),
#  ('employee',),
#  ('artist',),
#  ('pg_policy',),
#  ('circuits',),
#  ('support_contract_type',),
#  ('constructorresults',),
#  ('constructors',),
#  ('constructorstandings',),
#  ('drivers',),
#  ('driverstandings',),
#  ('laptimes',),
#  ('pitstops',),
#  ('qualifying',),
#  ('pg_settings',),
#  ('races',),
#  ('results',),
#  ('seasons',),
#  ('status',),
#  ('class',),
#  ('feature',),
#  ('district',),
#  ('pg_subscription',),
#  ('continent',),
#  ('pg_stat_user_tables',),
#  ('geoname',),
#  ('pg_stat_xact_user_tables',),
#  ('pg_attribute',),
#  ('pg_proc',),
#  ('pg_class',),
#  ('pg_attrdef',),
#  ('pg_constraint',),
#  ('pg_statio_all_tables',),
#  ('pg_statio_sys_tables',),
#  ('pg_statio_user_tables',),
#  ('pg_stat_all_indexes',),
# ...

# %%
# %sql SELECT * FROM tweet LIMIT 100;
# Out:
# 100 rows affected.
# [(721318437075685382, datetime.date(2016, 4, 16), datetime.time(12, 44), 'Bill Schulhoff', 'BillSchulhoff', 'Husband,Dad,GrandDad,Ordained Minister, Umpire, Poker Player, Mets, Jets, Rangers, LI Ducks, Sons of Anarchy, Survivor, Apprentice, O&A, & a good cigar', 'Wind 3.2 mph NNE. Barometer 30.20 in, Rising slowly. Temperature 49.3 °F. Rain today 0.00 in. Humidity 32%', None, None, 40.76027778, -72.95472222, 'US', 'East Patchogue, NY', 'http://pbs.twimg.com/profile_images/378800000718469152/535032cf772ca04524e0fe075d3b4767_normal.jpeg', 386, 705, 24, 'en', 'http://www.twitter.com/BillSchulhoff/status/721318437075685382'),
# ...

# %%
# %sql set schema 'tweet';
# Out:
# Done.
# []

# %%
# %sql SELECT * FROM information_schema.tables WHERE table_schema = 'tweet';
# Out:
# 7 rows affected.
# [('appdev', 'tweet', 'activity', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'tweet', 'membership', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'tweet', 'follower', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'tweet', 'list', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'tweet', 'message_with_counters', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'tweet', 'users', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'tweet', 'message', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None)]

# %%
# %sql SELECT * FROM tweet.activity LIMIT 100;
# Out:
# 100 rows affected.
# [(1, 1, datetime.datetime(2017, 10, 5, 16, 52, 21, 84706, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 'rt'),
#  (2, 1, datetime.datetime(2017, 10, 5, 16, 52, 21, 87525, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 'rt'),
#  (3, 1, datetime.datetime(2017, 10, 5, 16, 52, 21, 88640, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 'rt'),
#  (4, 1, datetime.datetime(2017, 10, 5, 16, 52, 21, 89631, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 'rt'),
#  (5, 1, datetime.datetime(2017, 10, 5, 16, 52, 21, 91242, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 'rt'),
#  (6, 1, datetime.datetime(2017, 10, 5, 16, 52, 21, 90695, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 'rt'),
#  (7, 1, datetime.datetime(2017, 10, 5, 16, 52, 21, 92545, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 'rt'),
# ...

# %%
# %sql select * FROM activity;
# Out:
# 3250 rows affected.
# [(1, 1, datetime.datetime(2017, 10, 5, 16, 52, 21, 84706, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 'rt'),
#  (2, 1, datetime.datetime(2017, 10, 5, 16, 52, 21, 87525, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 'rt'),
#  (3, 1, datetime.datetime(2017, 10, 5, 16, 52, 21, 88640, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 'rt'),
#  (4, 1, datetime.datetime(2017, 10, 5, 16, 52, 21, 89631, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 'rt'),
#  (5, 1, datetime.datetime(2017, 10, 5, 16, 52, 21, 91242, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 'rt'),
#  (6, 1, datetime.datetime(2017, 10, 5, 16, 52, 21, 90695, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 'rt'),
#  (7, 1, datetime.datetime(2017, 10, 5, 16, 52, 21, 92545, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 'rt'),
# ...

# %%
# %sql SELECT * FROM information_schema.tables WHERE table_schema = 'chinook';
# Out:
# 11 rows affected.
# [('appdev', 'chinook', 'invoice', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'chinook', 'customer', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'chinook', 'mediatype', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'chinook', 'playlist', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'chinook', 'genre', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'chinook', 'invoiceline', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'chinook', 'track', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'chinook', 'playlisttrack', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'chinook', 'employee', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
# ...
